# %%
import os
import pandas as pd
from sklearn.model_selection import train_test_split


DATA_FOLDER = "../data/raw/"

df = pd.DataFrame()
for file in os.listdir(DATA_FOLDER):
    df = pd.concat([df, pd.read_csv(os.path.join(DATA_FOLDER, file))])

df.head()
# Out:
#                                                 text  label
# 0  Używam od miesiąca, bardzo fajne słuchawki, ja...      2
# 1  Dla małych telefonów ok, choć plastik nie spra...      1
# 2  Całkiem ok trzyma się szyby jak nie odkleja si...      1
# 3  Łatwy montaż i dobrze trzyma się szyby. Szybki...      1
# 4  Bardzo fajna myszka o standardowym kształcie i...      2

# %%
def clean_text(text):
    # text = text.replace("\n", " ").replace("\t", " ")
    text = text.replace('"', '')
    return text

df["text"] = df["text"].apply(clean_text)

train_df, test_df = train_test_split(df, test_size=0.2, random_state=42)
train_df = train_df.reset_index(drop=True)
test_df = test_df.reset_index(drop=True)

train_df.to_csv("../data/processed/train.csv", index=False)
test_df.to_csv("../data/processed/test.csv", index=False)

# %%
train_df.head(10)
# Out:
#                                                 text  label
# 0  Po wyjęciu z opakowania wygląda na to że towar...      1
# 1  Nie polecam. Pasek miał być najwyższej jakości...      0
# 2  Zakupiony egzemplarz nie był dobrze spasowany,...      0
# 3  O Ile inny produkt tej firmy został mi polecon...      0
# 4  Po pierwsze szkło ewidentnie nie jest dedykowa...      0
# 5  Super uchwyt. Jak go dostałem myślałem że go z...      2
# 6  Nie ma tragedii, ale zastosowany materiał nie ...      1
# 7  Gorąco polecam tę szczotkę szczególnie właścic...      2
# 8  Porażka. Pomimo odkamieniania i czyszczenia uk...      0
# 9  Używam od miesiąca, bardzo fajne słuchawki, ja...      2

# %%
test_df.head()
# Out:
#                                                  text  label
# 21  Produkt posiada wszystkie wcięcia które powini...      1
# 37  Po niecałym dniu użytkowania szkło zaczęło się...      0
# 12  ciężko podważyć ich oryginalność, na co dostał...      0
# 26  Moja stara N72 padła po 8 latach użytkowania. ...      1
# 64  Sprzedającego ten produkt omijać z daleka. Spr...      0
